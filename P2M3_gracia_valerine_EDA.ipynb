# %%
# Import Libraries
import pandas as pd
import numpy as np

# %%
# Read data
df = pd.read_csv('P2M3_gracia_valerine_data_raw.csv', sep=",", encoding='Latin-1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['SALES'].max()
# Out:
# 14082.8

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# To be fixed columns:
#
# 5   ORDERDATE         2823 non-null   object  -> to datetime
# 16  ADDRESSLINE2      302 non-null    object  -> to drop
# 18  STATE             1337 non-null   object  -> to drop
# 19  POSTALCODE        2747 non-null   object  -> to drop
# 21  TERRITORY         1749 non-null   object  -> to drop
#
# Will be dropped because these columns have repititive information that is invaluable and will not disrupt the flow.

# %%
   # Load the data


    # Clean by dropping duplicates, formatting the data, and dropping unused/empty columns data
df.drop_duplicates(inplace=True)
df.columns = df.columns.str.lower().str.replace(' ', '_').str.strip()
df.drop(columns=['addressline2', 'state', 'territory', 'postalcode'], inplace=True)

    # Turning the cleaned data into new csv file
df.to_csv('P2M3_gracia_valerine_data_clean.csv', index=False)

# %%
ds = pd.read_csv('P2M3_gracia_valerine_data_clean.csv')
ds
# Out:
#       ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             orderdate    status  qtr_id  month_id  year_id  ... msrp  \
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ordernumber       2823 non-null   int64
#  1   quantityordered   2823 non-null   int64
#  2   priceeach         2823 non-null   float64
#  3   orderlinenumber   2823 non-null   int64
#  4   sales             2823 non-null   float64
#  5   orderdate         2823 non-null   object
#  6   status            2823 non-null   object
#  7   qtr_id            2823 non-null   int64
#  8   month_id          2823 non-null   int64
#  9   year_id           2823 non-null   int64
#  10  productline       2823 non-null   object
#  11  msrp              2823 non-null   int64
#  12  productcode       2823 non-null   object
#  13  customername      2823 non-null   object
#  14  phone             2823 non-null   object
#  15  addressline1      2823 non-null   object
# ...

# %%
ds['orderdate'].max()
# Out:
# '9/9/2004 0:00'

# %% [markdown]
# Notes:
#
# OBJECTIVE:
#
# This project is built to analyze sales performance, customer, product, order, profitability, revenue trends, and business strategy development. By assessing overall sales performance, understanding customer demographics and purchasing behavior, evaluating product performance and popularity, and analyzing order detail, trends, and revenue, we could develop effective business strategy based on data insights to improve sales and customer satisfaction.
